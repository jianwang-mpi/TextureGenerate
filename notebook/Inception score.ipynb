# %%
import cv2
from matplotlib import pyplot as plt
import os

path = '/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/market-origin-ssim/'
img = '0104_c3s1_017076_02.jpg'
path = os.path.join(path,img)
img = cv2.imread(path)
print(type(img[0][0][0]))

#img[:,:,:] = img * img_1
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# <class 'numpy.uint8'>

# %%
import cv2
from matplotlib import pyplot as plt
import os

path = '/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/market-textured-ssim-no-mask/PCB_256_L12018-11-16_17:53:20.894085_epoch_120/'
img = '0104_c3s1_017076_02.jpg'
path = os.path.join(path,img)
img = cv2.imread(path)
print(type(img[0][0][0]))

#img[:,:,:] = img * img_1
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# <class 'numpy.uint8'>

# %%
'/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/market-origin-ssim-no-mask/'
# Out:
# <class 'numpy.uint8'>

# %%
import cv2
from matplotlib import pyplot as plt
import os

path = '/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/market-textured-ssim/PCB_PerLoss_NoPosed2018-10-26_09:27:58.815980_epoch_120/'
img = '0104_c3s1_017076_02.jpg'
path = os.path.join(path,img)
img = cv2.imread(path)
print(type(img[0][0][0]))

#img[:,:,:] = img * img_1
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
p = '/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/market-origin-ssim/22'

p = p[p.find('market-origin-ssim'):]
p = p[p.find('/')+1:]
p

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

path = '/unsullied/sharefs/zhongyunshan/isilon-home/datasets/Texture/deepfashion-pose/query/0000000102_2side.jpg.npy'

pose = np.load(path,encoding='latin1')
